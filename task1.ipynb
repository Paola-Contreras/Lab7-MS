# %% [markdown]
# ## Laboratorio no.7
#
# - Paola de León 20361
# - Gabriela Contreras 20213

# %%
# Imports 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Generación de datos  
n = 100
presupuesto = np.linspace(100, 1000, n)

# Generar datos de CTR relacionados con el presupuesto 
CTR = 2.5 + 0.025 * presupuesto 

# Agregar ruido para simular variabilidad
ruido = np.random.normal(0, 2, n)
CTR += ruido

#------------------------------------------------------------------------------------------------------------
# Crear un modelo sustituto utilizando una regresión polinómica
degree = 2  # Grado del polinomio
poly_features = PolynomialFeatures(degree=degree)
X_poly = poly_features.fit_transform(presupuesto.reshape(-1, 1))
model = LinearRegression()
model.fit(X_poly, CTR)

#------------------------------------------------------------------------------------------------------------
# Realizar predicciones
presupuesto_pred = np.linspace(100, 1000, 100)  # Valores de presupuesto para predicción
X_pred = poly_features.transform(presupuesto_pred.reshape(-1, 1))
CTR_pred = model.predict(X_pred)

#------------------------------------------------------------------------------------------------------------
# Graficar  
plt.figure(figsize=(10, 6))
plt.scatter(presupuesto, CTR, label="Datos reales", color="#57abf0")
plt.plot(presupuesto_pred, CTR_pred, label="Predicciones", color="#ee5962")
plt.xlabel("Presupuesto")
plt.ylabel("Tasa de Clics (CTR)")
plt.title("Modelo Sustituto de Regresión Polinómica")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - ¿Por qué este es un ejemplo de meta-modelado?
#     - Este es un ejemplo de meta modelo puesto a que se emplea una regresión polémica para modelar la relación entre la tasa de clics y el presupuesto. En este caso se hace uso de un polinomio de segundo grado para representar dicha relación

# %% [markdown]
# - ¿Cuál es el modelo sustitutivo?
#     - En el ejercicio anterior, utilizamos un modelo de regresión polinómica de grado 2 como un sustituto para aproximarnos a la relación entre el presupuesto invertido y la cantidad de clics generados en una campaña de publicidad digital, dicha eleccion nos permitió capturar de manera más precisa la naturaleza no lineal de la relación entre estas dos variables.
